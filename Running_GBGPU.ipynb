# %% [markdown]
# <a href="https://colab.research.google.com/github/vaidehi2002vd/Notebooks/blob/main/Running_GBGPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2023-06-21 21:22:27--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   201MB/s    in 0.4s
#
# 2023-06-21 21:22:27 (201 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# %%
# !conda install numpy
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     ca-certificates-2023.05.30 |       h06a4308_0         120 KB
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     conda-23.1.0               |   py37h06a4308_0         937 KB
#     flit-core-3.6.0            |     pyhd3eb1b0_0          42 KB
#     importlib-metadata-4.11.3  |   py37h06a4308_0          40 KB
#     importlib_metadata-4.11.3  |       hd3eb1b0_0          12 KB
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
# ...

# %%
# !conda install pandas
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.4           |   py37hce1f21e_0         126 KB
#     numexpr-2.8.1              |   py37h6abb31d_0         123 KB
#     packaging-22.0             |   py37h06a4308_0          68 KB
# ...

# %%
# !conda install gcc_linux-64 gxx_linux-64 gsl numpy Cython scipy jupyter ipython h5py matplotlib
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
# !git clone https://github.com/mikekatz04/GBGPU.git
# Out:
# Cloning into 'GBGPU'...
# remote: Enumerating objects: 1187, done.
# remote: Counting objects: 100% (361/361), done.
# remote: Compressing objects: 100% (224/224), done.
# remote: Total 1187 (delta 193), reused 249 (delta 137), pack-reused 826
# Receiving objects: 100% (1187/1187), 12.31 MiB | 7.56 MiB/s, done.
# Resolving deltas: 100% (683/683), done.

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating gbgpu.egg-info
# writing gbgpu.egg-info/PKG-INFO
# writing dependency_links to gbgpu.egg-info/dependency_links.txt
# writing top-level names to gbgpu.egg-info/top_level.txt
# writing manifest file 'gbgpu.egg-info/SOURCES.txt'
# package init file 'gbgpu/utils/__init__.py' not found (or not a regular file)
# reading manifest file 'gbgpu.egg-info/SOURCES.txt'
# writing manifest file 'gbgpu.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/gbgpu
# copying gbgpu/__init__.py -> build/lib.linux-x86_64-3.7/gbgpu
# copying gbgpu/gbgpu.py -> build/lib.linux-x86_64-3.7/gbgpu
# copying gbgpu/thirdbody.py -> build/lib.linux-x86_64-3.7/gbgpu
# creating build/lib.linux-x86_64-3.7/gbgpu/utils
# copying gbgpu/utils/constants.py -> build/lib.linux-x86_64-3.7/gbgpu/utils
# ...

# %%
cd ..
# Out:
# /content

# %%
# !git clone git@github.com:mikekatz04/LISAanalysistools.git
# Out:
# Cloning into 'LISAanalysistools'...
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !unzip LISAanalysistools-dev.zip
# Out:
# Archive:  LISAanalysistools-dev.zip
# 838023cdc44f8a923d3365760986293126c7f24b
#    creating: LISAanalysistools-dev/
#   inflating: LISAanalysistools-dev/.gitignore
#   inflating: LISAanalysistools-dev/README.md
#   inflating: LISAanalysistools-dev/bulk_gb_search.py
#    creating: LISAanalysistools-dev/docs/
#  extracting: LISAanalysistools-dev/docs/.nojekyll
#   inflating: LISAanalysistools-dev/docs/Makefile
#    creating: LISAanalysistools-dev/docs/doctrees/
#   inflating: LISAanalysistools-dev/docs/doctrees/README.doctree
#   inflating: LISAanalysistools-dev/docs/doctrees/environment.pickle
#   inflating: LISAanalysistools-dev/docs/doctrees/index.doctree
#   inflating: LISAanalysistools-dev/docs/doctrees/lisatools_tutorial.doctree
#    creating: LISAanalysistools-dev/docs/doctrees/nbsphinx/
#   inflating: LISAanalysistools-dev/docs/doctrees/nbsphinx/lisatools_tutorial.ipynb
#    creating: LISAanalysistools-dev/docs/doctrees/user/
# ...

# %%
cd LISAanalysistools-dev/
# Out:
# /content/LISAanalysistools-dev

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating LISAanalysistools.egg-info
# writing LISAanalysistools.egg-info/PKG-INFO
# writing dependency_links to LISAanalysistools.egg-info/dependency_links.txt
# writing top-level names to LISAanalysistools.egg-info/top_level.txt
# writing manifest file 'LISAanalysistools.egg-info/SOURCES.txt'
# reading manifest file 'LISAanalysistools.egg-info/SOURCES.txt'
# writing manifest file 'LISAanalysistools.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/lisatools
# copying lisatools/sensitivity.py -> build/lib/lisatools
# copying lisatools/glitch.py -> build/lib/lisatools
# copying lisatools/diagnostic.py -> build/lib/lisatools
# copying lisatools/__init__.py -> build/lib/lisatools
# creating build/lib/lisatools/sampling
# copying lisatools/sampling/samplingguide.py -> build/lib/lisatools/sampling
# ...

# %%
cd ..
# Out:
# /content

# %%
# !pip install eryn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 104 kB 9.6 MB/s
# ...

# %%
# !pip install pymcmcstat
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 136 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 9.9 MB 40.3 MB/s
# ...
#      |████████████████████████████████| 293 kB 62.1 MB/s
# ...
#      |████████████████████████████████| 233 kB 59.2 MB/s
# ...
#      |████████████████████████████████| 75 kB 284 kB/s
# ...
